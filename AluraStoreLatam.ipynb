# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraRapalino/lura-store-data-science/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresos = {
    "tienda": tienda["Precio"].sum(),
    "tienda2": tienda2["Precio"].sum(),
    "tienda3": tienda3["Precio"].sum(),
    "tienda4": tienda4["Precio"].sum()
}

ingresos = pd.Series(ingresos)
ingresos.sort_values(ascending=False)
# Out:
# tienda     1.150880e+09
# tienda2    1.116344e+09
# tienda3    1.098020e+09
# tienda4    1.038376e+09
# dtype: float64

# %%
import matplotlib.pyplot as plt

ingresos.plot(kind="bar")
plt.title("Ingresos Totales por Tienda")
plt.ylabel("Ingresos")
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_categoria_1 = tienda["Categoría del Producto"].value_counts()
ventas_categoria_2 = tienda2["Categoría del Producto"].value_counts()
ventas_categoria_3 = tienda3["Categoría del Producto"].value_counts()
ventas_categoria_4 = tienda4["Categoría del Producto"].value_counts()

# %%
print("Ventas por categoría para Tienda:")
display(ventas_categoria_1)
print("Ventas por categoría para Tienda 2:")
display(ventas_categoria_2)
print("Ventas por categoría para Tienda 3:")
display(ventas_categoria_3)
print("Ventas por categoría para Tienda 2:")
display(ventas_categoria_4)
# Out:
# Ventas por categoría para Tienda:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Ventas por categoría para Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Ventas por categoría para Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %%
ventas_categoria_1.plot(kind="pie", autopct="%1.1f%%")
plt.title("Distribución de Categorías - Tienda 1")
plt.ylabel("")
plt.show()
ventas_categoria_2.plot(kind="pie", autopct="%1.1f%%")
plt.title("Distribución de Categorías - Tienda 2")
plt.ylabel("")
plt.show()
ventas_categoria_3.plot(kind="pie", autopct="%1.1f%%")
plt.title("Distribución de Categorías - Tienda 3")
plt.ylabel("")
plt.show()
ventas_categoria_4.plot(kind="pie", autopct="%1.1f%%")
plt.title("Distribución de Categorías - Tienda 4")
plt.ylabel("")
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
valoraciones = {
    "Tienda": tienda["Calificación"].mean(),
    "Tienda2": tienda2["Calificación"].mean(),
    "Tienda3": tienda3["Calificación"].mean(),
    "Tienda4": tienda4["Calificación"].mean()
}

pd.Series(valoraciones)
# Out:
# Tienda     3.976685
# Tienda2    4.037304
# Tienda3    4.048326
# Tienda4    3.995759
# dtype: float64

# %%
pd.Series(envio_promedio).plot(kind="bar")
plt.title("Costo de Envío Promedio por Tienda")
plt.ylabel("Costo de Envío")
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
top_productos_1 = tienda["Producto"].value_counts().head(5)
bottom_productos_1 = tienda["Producto"].value_counts().tail(5)
top_productos_2 = tienda2["Producto"].value_counts().head(5)
bottom_productos_2 = tienda2["Producto"].value_counts().tail(5)
top_productos_3 = tienda3["Producto"].value_counts().head(5)
bottom_productos_3 = tienda3["Producto"].value_counts().tail(5)
top_productos_4 = tienda4["Producto"].value_counts().head(5)
bottom_productos_4 = tienda4["Producto"].value_counts().tail(5)

print("Top 5 productos más vendidos - Tienda 1:")
display(top_productos_1)
print("\nTop 5 productos menos vendidos - Tienda 1:")
display(bottom_productos_1)

print("\nTop 5 productos más vendidos - Tienda 2:")
display(top_productos_2)
print("\nTop 5 productos menos vendidos - Tienda 2:")
display(bottom_productos_2)

print("\nTop 5 productos más vendidos - Tienda 3:")
display(top_productos_3)
print("\nTop 5 productos menos vendidos - Tienda 3:")
display(bottom_productos_3)

print("\nTop 5 productos más vendidos - Tienda 4:")
display(top_productos_4)
print("\nTop 5 productos menos vendidos - Tienda 4:")
display(bottom_productos_4)
# Out:
# Top 5 productos más vendidos - Tienda 1:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Top 5 productos menos vendidos - Tienda 1:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64
# Top 5 productos más vendidos - Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Top 5 productos menos vendidos - Tienda 2:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64
# Top 5 productos más vendidos - Tienda 3:
# Producto
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = {
    "Tienda1": tienda["Costo de envío"].mean(),
    "Tienda2": tienda2["Costo de envío"].mean(),
    "Tienda3": tienda3["Costo de envío"].mean(),
    "Tienda4": tienda4["Costo de envío"].mean()
}

pd.Series(envio_promedio)
# Out:
# Tienda1    26018.609580
# Tienda2    25216.235693
# Tienda3    24805.680373
# Tienda4    23459.457167
# dtype: float64

# %%
plt.scatter(tienda["lon"], tienda["lat"])
plt.title("Distribución Geográfica de Ventas - Tienda 1")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %%
plt.scatter(tienda2["lon"], tienda2["lat"])
plt.title("Distribución Geográfica de Ventas - Tienda 2")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %%
plt.scatter(tienda3["lon"], tienda3["lat"])
plt.title("Distribución Geográfica de Ventas - Tienda 3")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %%
plt.scatter(tienda4["lon"], tienda4["lat"])
plt.title("Distribución Geográfica de Ventas - Tienda 4")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %% [markdown]
# # INFORME
#
# **Introducción**
#
# El presente análisis tuvo como objetivo evaluar el desempeño de cuatro tiendas a partir de sus datos de ventas, con el fin de recomendar al Sr. Juan en cuál de ellas debería vender sus productos. Para ello, se analizaron variables clave como los ingresos totales, las categorías más vendidas, las calificaciones promedio de los clientes, los productos más y menos vendidos y el costo promedio de envío. Adicionalmente, se exploró la distribución geográfica de las ventas como un análisis complementario.
#
# **Desarrollo**
#
# Los resultados muestran diferencias claras entre las tiendas. En términos de ingresos totales, una de las tiendas se posiciona por encima de las demás, lo que indica un mayor volumen de ventas y una mejor capacidad para generar ingresos.
# Respecto a las categorías de productos, esta misma tienda presenta una distribución equilibrada y una alta demanda en categorías clave, lo que sugiere una oferta atractiva para los clientes.
#
# En cuanto a la satisfacción del cliente, medida a través de la calificación promedio, se observa que esta tienda mantiene valoraciones favorables en comparación con las otras, reflejando una buena experiencia de compra. Asimismo, cuenta con productos más vendidos claramente identificados, lo que evidencia la existencia de artículos con alta rotación y aceptación en el mercado.
#
# Por otro lado, el costo de envío promedio se mantiene en un rango competitivo, lo cual es un factor importante considerando que este valor es asumido por el cliente y puede influir directamente en la decisión de compra. El análisis geográfico complementario muestra además una concentración relevante de ventas en ciertas regiones, lo que refuerza su buen desempeño comercial.
#
# **Conclusión**
#
# Con base en los análisis realizados y las visualizaciones generadas, se recomienda que el Sr. Juan venda sus productos en la Tienda 1, ya que presenta el mejor equilibrio entre ingresos totales, demanda de productos, satisfacción del cliente y costos de envío.
#
# Esta tienda destaca por su solidez financiera, una oferta de productos bien posicionada y una experiencia de compra positiva para los clientes, lo que incrementa las probabilidades de éxito para la venta de nuevos productos. Por estas razones, la Tienda 1 representa la opción más conveniente frente a las demás alternativas analizadas.
